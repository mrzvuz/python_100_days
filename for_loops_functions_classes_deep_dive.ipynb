# %% [markdown]
# # For Loops, Functions, and Classes: Beginner Deep Dive
#
# This notebook focuses on three important Python ideas:
#
# 1. `for` loops
# 2. `while` loops
# 3. functions
# 4. classes
#
# These three topics often feel confusing because they all involve names, blocks of code, and values moving around. The goal here is to slow everything down and make the flow visible.

# %% [markdown]
# ## 1. For Loops
#
# A `for` loop repeats code for each item in a collection.
#
# Think of it like this:
#
# `for each item in this group, do this action`
#
# The variable after `for` is temporary. It changes automatically each time the loop runs.

# %%
students = ["Adam", "Sara", "Mehmet", "Lina"]

for student in students:
    print("Hello", student)
# Out:
# Hello Adam
# Hello Sara
# Hello Mehmet
# Hello Lina

# %% [markdown]
# What Python does:
#
# 1. First loop: `student = "Adam"`
# 2. Second loop: `student = "Sara"`
# 3. Third loop: `student = "Mehmet"`
# 4. Fourth loop: `student = "Lina"`
#
# You do not manually change `student`. Python changes it for you.

# %% [markdown]
# ## For Loop Example With 4 Values Per Item
#
# Each product below has 4 pieces of information:
#
# 1. product name
# 2. category
# 3. price
# 4. stock quantity
#
# This is a good way to understand how loops work with structured data.

# %%
products = [
    ["Laptop", "Electronics", 1200, 5],
    ["Mouse", "Electronics", 25, 50],
    ["Notebook", "Stationery", 4, 100],
    ["Chair", "Furniture", 80, 10],
]

for product in products:
    name = product[0]
    category = product[1]
    price = product[2]
    stock = product[3]
    total_value = price * stock

    print(name, "|", category, "|", "Total value:", "${:.2f}".format(total_value))
# Out:
# Laptop | Electronics | Total value: $6000.00
# Mouse | Electronics | Total value: $1250.00
# Notebook | Stationery | Total value: $400.00
# Chair | Furniture | Total value: $800.00

# %% [markdown]
# Inside the loop, `product` becomes one list at a time.
#
# First time:
#
# `product = ["Laptop", "Electronics", 1200, 5]`
#
# Second time:
#
# `product = ["Mouse", "Electronics", 25, 50]`
#
# The loop is simply repeating the same logic for every product.

# %% [markdown]
# ## 2. While Loops
#
# A `while` loop repeats code while a condition is `True`.
#
# Think of it like this:
#
# `while this condition is still true, keep doing this action`
#
# The most important thing with a `while` loop is that something inside the loop must eventually make the condition become `False`. Otherwise, the loop can run forever.

# %%
count = 1

while count <= 5:
    print("Count:", count)
    count = count + 1
# Out:
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5

# %% [markdown]
# What Python does:
#
# 1. `count` starts as `1`.
# 2. Python checks: is `count <= 5`?
# 3. If yes, it runs the loop body.
# 4. Inside the loop, `count` increases by `1`.
# 5. Eventually `count` becomes `6`.
# 6. Now `count <= 5` is `False`, so the loop stops.
#
# With a `for` loop, Python moves through a collection for you.
#
# With a `while` loop, you are responsible for changing the condition.

# %% [markdown]
# ## While Loop Example With 4 Values
#
# This example simulates saving money toward a goal.
#
# We use 4 values:
#
# 1. starting balance
# 2. weekly saving amount
# 3. target amount
# 4. week counter

# %%
balance = 100
weekly_saving = 50
target = 300
week = 1

while balance < target:
    print("Week", week, "| Balance before saving:", balance)
    balance = balance + weekly_saving
    week = week + 1

print("Goal reached! Final balance:", balance)
# Out:
# Week 1 | Balance before saving: 100
# Week 2 | Balance before saving: 150
# Week 3 | Balance before saving: 200
# Week 4 | Balance before saving: 250
# Goal reached! Final balance: 300

# %% [markdown]
# When should you use a `while` loop?
#
# Use a `while` loop when you do not know exactly how many times the loop should run.
#
# Examples:
#
# - keep asking for a password until it is correct
# - keep saving money until a goal is reached
# - keep reading data until there is no more data
# - keep running a game until the player quits

# %% [markdown]
# ## 3. Functions
#
# A function is reusable code.
#
# Think of a function like a small machine:
#
# 1. You give it inputs.
# 2. It does work.
# 3. It can return an output.
#
# The names inside the parentheses are called **parameters**.

# %% [markdown]
# ## Function With 3 Parameters
#
# This function receives:
#
# 1. first name
# 2. last name
# 3. city

# %%
def introduce_person(first_name, last_name, city):
    message = f"Hello, my name is {first_name} {last_name}. I live in {city}."
    return message

result = introduce_person("Adam", "Smith", "Istanbul")
print(result)
# Out:
# Hello, my name is Adam Smith. I live in Istanbul.

# %% [markdown]
# `first_name`, `last_name`, and `city` are parameters.
#
# `"Adam"`, `"Smith"`, and `"Istanbul"` are arguments.
#
# Parameters are placeholders. Arguments are the real values.

# %% [markdown]
# ## Function With 4 Parameters
#
# This function calculates the total price of an order.
#
# It receives:
#
# 1. product name
# 2. quantity
# 3. price per item
# 4. tax rate

# %%
def calculate_order_total(product_name, quantity, price_each, tax_rate):
    subtotal = quantity * price_each
    tax = subtotal * tax_rate
    total = subtotal + tax

    return f"{product_name} total: ${total:.2f}"

print(calculate_order_total("Notebook", 3, 15, 0.20))
print(calculate_order_total("Pen", 10, 2, 0.20))
# Out:
# Notebook total: $54.00
# Pen total: $24.00

# %% [markdown]
# Why functions are useful:
#
# Without the function, you would repeat the same calculation again and again.
#
# With the function, you write the calculation once and reuse it with different values.

# %% [markdown]
# ## Function With 5 Parameters
#
# This function creates a student report.
#
# It receives:
#
# 1. student name
# 2. math score
# 3. English score
# 4. science score
# 5. attendance status

# %%
def create_student_report(name, math_score, english_score, science_score, attendance):
    average = (math_score + english_score + science_score) / 3

    report = {
        "name": name,
        "math": math_score,
        "english": english_score,
        "science": science_score,
        "average": average,
        "attendance": attendance,
    }

    return report

report_one = create_student_report(
    name="Sara", 
    math_score=90, 
    english_score=85, 
    science_score=95, 
    attendance="Excellent"
)

report_two = create_student_report(
    name="Mehmet", 
    math_score=70, 
    english_score=75, 
    science_score=80, 
    attendance="Good"
)

print(report_one)
print(report_two)
# Out:
# {'name': 'Sara', 'math': 90, 'english': 85, 'science': 95, 'average': 90.0, 'attendance': 'Excellent'}
# {'name': 'Mehmet', 'math': 70, 'english': 75, 'science': 80, 'average': 75.0, 'attendance': 'Good'}

# %% [markdown]
# The most important function pattern:
#
# `define once, use many times`
#
# If you copy and paste the same code many times, it might be a good function.

# %% [markdown]
# ## 4. Classes
#
# A class is a blueprint for creating objects.
#
# A class groups together:
#
# 1. data
# 2. actions
#
# Example:
#
# A student has data: name, age, city, course, grade.
#
# A student can do actions: introduce themselves, check if passing.

# %% [markdown]
# ## Class With 5 Parameters
#
# `__init__` runs automatically when you create a new object.
#
# `self` means: this specific object.

# %%
class Student:
    def __init__(self, name, age, city, course, grade):
        self.name = name
        self.age = age
        self.city = city
        self.course = course
        self.grade = grade

    def introduce(self):
        return f"My name is {self.name}. I am learning {self.course}."

    def is_passing(self):
        return self.grade >= 50

student_one = Student("Adam", 25, "Istanbul", "Python", 88)
student_two = Student("Lina", 22, "Ankara", "Data Analysis", 45)

print(student_one.introduce())
print(student_one.is_passing())

print(student_two.introduce())
print(student_two.is_passing())
# Out:
# My name is Adam. I am learning Python.
# True
# My name is Lina. I am learning Data Analysis.
# False

# %% [markdown]
# Important class vocabulary:
#
# - `Student` is the class.
# - `student_one` is an object.
# - `student_two` is another object.
# - `name`, `age`, `city`, `course`, and `grade` are object data.
# - `introduce()` and `is_passing()` are methods.
#
# A method is just a function inside a class.

# %% [markdown]
# ## Class With 4 Parameters
#
# This class represents a bank account.
#
# It receives:
#
# 1. owner
# 2. bank name
# 3. account type
# 4. balance

# %%
class BankAccount:
    def __init__(self, owner, bank_name, account_type, balance):
        self.owner = owner
        self.bank_name = bank_name
        self.account_type = account_type
        self.balance = balance

    def deposit(self, amount):
        self.balance = self.balance + amount
        return self.balance

    def withdraw(self, amount):
        if amount > self.balance:
            return "Not enough money"

        self.balance = self.balance - amount
        return self.balance

    def summary(self):
        return f"{self.owner} has ${self.balance} in a {self.account_type} account."

account = BankAccount("Adam", "Python Bank", "Savings", 1000)

print(f"Summary: {account.summary()}")
print(f"Deposited: ${account.deposit(250):,.2f}")
print(f"Withdrawn: ${account.withdraw(400):,.2f}")
print(f"Summary: {account.summary()}")
# Out:
# Summary: Adam has $1000 in a Savings account.
# Deposited: $1,250.00
# Withdrawn: $850.00
# Summary: Adam has $850 in a Savings account.

# %% [markdown]
# Notice the difference:
#
# A function usually works with values you pass into it.
#
# A class creates objects that remember their own values over time.
#
# The bank account remembers its balance after deposit and withdrawal.

# %% [markdown]
# ## Putting All Three Together
#
# Now we will use:
#
# 1. a class to represent products
# 2. a function to print a product summary
# 3. a for loop to repeat the summary for every product

# %%
class Product:
    def __init__(self, name, category, price, stock):
        self.name = name
        self.category = category
        self.price = price
        self.stock = stock

    def total_stock_value(self):
        return self.price * self.stock


def print_product_summary(name, category, price, stock, total_value):
    print(f"{name} | {category} | price: {price} | stock: {stock} | value: {total_value}")


products = [
    Product("Laptop", "Electronics", 1200, 5),
    Product("Mouse", "Electronics", 25, 50),
    Product("Notebook", "Stationery", 4, 100),
]

for product in products:
    print_product_summary(
        product.name,
        product.category,
        product.price,
        product.stock,
        product.total_stock_value(),
    )
# Out:
# Laptop | Electronics | price: 1200 | stock: 5 | value: 6000
# Mouse | Electronics | price: 25 | stock: 50 | value: 1250
# Notebook | Stationery | price: 4 | stock: 100 | value: 400

# %% [markdown]
# What happened?
#
# 1. `Product` is a class.
# 2. `Product(...)` creates product objects.
# 3. `products` is a list of product objects.
# 4. The `for` loop goes through one product at a time.
# 5. The function receives 5 values and prints a clean summary.
#
# This is a very common Python pattern.

# %% [markdown]
# ## Exercises
#
# Try these before looking at the solution.
#
# 1. Create a list of 5 cities and use a `for` loop to print each city.
# 2. Create a function called `calculate_salary` with 4 parameters: `employee_name`, `hours_worked`, `hourly_rate`, and `bonus`. Return the total salary.
# 3. Create a class called `Course` with 5 parameters: `title`, `teacher`, `duration_weeks`, `level`, and `price`.
# 4. Add a method to `Course` called `describe()` that returns a sentence about the course.
# 5. Create 3 course objects, put them in a list, and use a `for` loop to print each course description.

# %%
# 1. Exercise: Create a list of cities and print each city using a for loop. 
cities = ["Istanbul", "Ankara", "Izmir", "Bursa", "Antalya"]
for city in cities:
    print(city)

# -----------------------------------------------------------------------------

# 2. Create a function that calculates the salary of an employee based on their name, hours worked, hourly rate, and bonus. Finally, call the function and print the result.
def calculate_salary(employee_name, hours_worked, hourly_rate, bonus):
    total_salary = (hours_worked * hourly_rate) + bonus
    return f"{employee_name}'s salary is: ${total_salary:.2f}"

print(calculate_salary("Adam", 40, 25, 100))

# -----------------------------------------------------------------------------

class Course:
    def __init__(self,title, teacher, duration_weeks, level, price):
        self.title = title
        self.teacher = teacher
        self.duration_weeks = duration_weeks
        self.level = level
        self.price = price

    def describe(self):
        return f"{self.title} is a {self.level} course taught by {self.teacher}. It lasts for {self.duration_weeks} weeks and costs ${self.price:.2f}."
    
course_one = Course("Python Programming", "Adam Smith", 8, "Beginner", 199)
course_two = Course("Data Analysis", "Lina Johnson", 10, "Intermediate", 299)
course_three = Course("Machine Learning", "Mehmet Yilmaz", 12, "Advanced", 399)
print(course_one.describe())
print(course_two.describe())
print(course_three.describe())
# Out:
# Istanbul
# Ankara
# Izmir
# Bursa
# Antalya
# Adam's salary is: $1100.00
# Python Programming is a Beginner course taught by Adam Smith. It lasts for 8 weeks and costs $199.00.
# Data Analysis is a Intermediate course taught by Lina Johnson. It lasts for 10 weeks and costs $299.00.
# Machine Learning is a Advanced course taught by Mehmet Yilmaz. It lasts for 12 weeks and costs $399.00.

# %% [markdown]
# ## Possible Solution

# %%
# 1. For loop with cities
cities = ["Istanbul", "Ankara", "Izmir", "Bursa", "Antalya"]

for city in cities:
    print(city)


# 2. Function with 4 parameters
def calculate_salary(employee_name, hours_worked, hourly_rate, bonus):
    salary = hours_worked * hourly_rate + bonus
    return f"{employee_name}'s salary is {salary}"


print(calculate_salary("Adam", 40, 25, 200))


# 3, 4, and 5. Class with 5 parameters, method, objects, list, and loop
class Course:
    def __init__(self, title, teacher, duration_weeks, level, price):
        self.title = title
        self.teacher = teacher
        self.duration_weeks = duration_weeks
        self.level = level
        self.price = price

    def describe(self):
        return f"{self.title} is taught by {self.teacher}. It is {self.level}, lasts {self.duration_weeks} weeks, and costs {self.price}."


courses = [
    Course("Python Basics", "Sara", 6, "Beginner", 100),
    Course("Data Analysis", "Mehmet", 8, "Intermediate", 150),
    Course("Machine Learning", "Lina", 10, "Advanced", 250),
]

for course in courses:
    print(course.describe())
# Out:
# Istanbul
# Ankara
# Izmir
# Bursa
# Antalya
# Adam's salary is 1200
# Python Basics is taught by Sara. It is Beginner, lasts 6 weeks, and costs 100.
# Data Analysis is taught by Mehmet. It is Intermediate, lasts 8 weeks, and costs 150.
# Machine Learning is taught by Lina. It is Advanced, lasts 10 weeks, and costs 250.

# %% [markdown]
# ## Quick Memory Guide
#
# `for` loop: use it when you want to repeat an action for every item.
#
# `function`: use it when you want reusable code that receives inputs.
#
# `class`: use it when you want to model a real thing that has data and actions.
#
# A simple way to remember:
#
# - loop = repeat
# - function = reusable action
# - class = blueprint for objects
